# %% [markdown]
# Fecha limite de entrega: semana de inicio de Parciales
#
# ## Proyecto Final
#
# - Instalacion de librerias, si es necesario
#
# - Importacion de librerias
#
# - Calculo de la clave privada y publica por parte de Alice
#
# - Calculo de la clave privada y publica por parte de Bob
#
# - Calculo de la clave comprtida por parte de Alice
#
# - Calculo de la clave comprtida por parte de Bob
#
# - Verificacion
#
# - Derivacion de clave (HKDF)
#
# - Generacion de texto (aleatorio)(por parte de Alice) usando AES-G-CM
#
# - Bob descifra
#
# Consideracion: imprimiendo cada bloque, para que sea visible el proceso
#
# --------------------------------------
#
# Variante: EL GAMAL (investigar)

# %% [markdown]
# -----------------------------------
#
# El proyecto final se envía al siguiente correo: contacto@cccma.club
# En caso de que no ejecuté el código o no se figura presencia en ninguna de las listas no se considera la entrega.
